# %%
# %pip install -U scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 12.9 MB/s eta 0:00:00 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 46.9 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 40.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 50.9 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install scikit-learn
# !pip install seaborn
# !pip install matplotlib

# %%
# importamos las librerías que necesitamos
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# %%
# Imputación de nulos usando métodos avanzados estadísticos
# -----------------------------------------------------------------------
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# %%
# Librerías de visualización
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt
# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
df=pd.read_csv("world_data_full_apply.csv", index_col=0)
df
# Out:
#          country  density abbreviation  agricultural_land  land_area  \
# 0    Afghanistan     60.0           AF               58.1    652.230
# 1        Albania    105.0           AL               43.1     28.748
# 2        Algeria     18.0           DZ               17.4        NaN
# 3        Andorra    164.0           AD               40.0    468.000
# 4         Angola     26.0           AO               47.5        NaN
# ..           ...      ...          ...                ...        ...
# 190    Venezuela     32.0           VE               24.5    912.050
# 191      Vietnam    314.0           VN               39.3    331.210
# 192        Yemen     56.0           YE               44.6    527.968
# 193       Zambia     25.0           ZM               32.1    752.618
# 194     Zimbabwe     38.0           ZW               41.9    390.757
#
#      armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0                323.0       32.49          93.0              Kabul
# ...

# %%
# O método .fillna() em pandas é usado para preencher valores nulos (NaN) em um DataFrame ou Series com algum valor específico ou estratégia.

# %%
# 🧠 O que ele faz:
# Substitui os valores NaN por:
# um valor constante (como 0, "desconhecido", etc.),
# a média ou mediana de uma coluna,
# o valor anterior ou seguinte (forward/backward fill).

# %%
""" | `strategy`        | O que faz                                                           |
| ----------------- | ------------------------------------------------------------------- |
| `'mean'`          | Substitui `NaN` pela média da coluna                                |
| `'median'`        | Substitui `NaN` pela mediana da coluna                              |
| `'most_frequent'` | Substitui `NaN` pelo valor mais frequente (moda)                    |
| `'constant'`      | Substitui `NaN` por um valor constante definido em `fill_value=...` | """
# Out:
# " | `strategy`        | O que faz                                                           |\n| ----------------- | ------------------------------------------------------------------- |\n| `'mean'`          | Substitui `NaN` pela média da coluna                                |\n| `'median'`        | Substitui `NaN` pela mediana da coluna                              |\n| `'most_frequent'` | Substitui `NaN` pelo valor mais frequente (moda)                    |\n| `'constant'`      | Substitui `NaN` por um valor constante definido em `fill_value=...` | "
